# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pprint

# %%
df = pd.read_csv("dataset.csv").copy()
df.head()
# Out:
#    Unnamed: 0  Time Serie AUSTRALIA - AUSTRALIAN DOLLAR/US$  \
# 0           0  2000-01-03                            1.5172
# 1           1  2000-01-04                            1.5239
# 2           2  2000-01-05                            1.5267
# 3           3  2000-01-06                            1.5291
# 4           4  2000-01-07                            1.5272
#
#   EURO AREA - EURO/US$ NEW ZEALAND - NEW ZELAND DOLLAR/US$  \
# 0               0.9847                              1.9033
# 1                 0.97                              1.9238
# 2               0.9676                              1.9339
# 3               0.9686                              1.9436
# 4               0.9714                               1.938
#
#   UNITED KINGDOM - UNITED KINGDOM POUND/US$ BRAZIL - REAL/US$  \
# 0                                    0.6146             1.805
# 1                                    0.6109            1.8405
# ...

# %%
df.describe(include="all")
# Out:
#          Unnamed: 0  Time Serie AUSTRALIA - AUSTRALIAN DOLLAR/US$  \
# count   5217.000000        5217                              5217
# unique          NaN        5217                              2959
# top             NaN  2011-10-21                                ND
# freq            NaN           1                               198
# mean    2608.000000         NaN                               NaN
# std     1506.162508         NaN                               NaN
# min        0.000000         NaN                               NaN
# 25%     1304.000000         NaN                               NaN
# 50%     2608.000000         NaN                               NaN
# 75%     3912.000000         NaN                               NaN
# max     5216.000000         NaN                               NaN
#
#        EURO AREA - EURO/US$ NEW ZEALAND - NEW ZELAND DOLLAR/US$  \
# count                  5217                                5217
# ...

# %% [markdown]
# <center><h1>"AUSTRALIA - AUSTRALIAN DOLLAR/US$"</h1></center>

# %%
counts = df["AUSTRALIA - AUSTRALIAN DOLLAR/US$"].value_counts()
percent = df["AUSTRALIA - AUSTRALIAN DOLLAR/US$"].value_counts(normalize=True) * 100
pd.DataFrame({"Count":counts,"Percentage":percent}).head(10)
# Out:
#         Count  Percentage
# ND        198    3.795285
# 1.3033      8    0.153345
# 1.3263      8    0.153345
# 1.3943      8    0.153345
# 1.2958      7    0.134177
# 1.3287      7    0.134177
# 1.3026      7    0.134177
# 1.3031      7    0.134177
# 1.3215      7    0.134177
# 1.3305      7    0.134177

# %%
percentage_nan = df["AUSTRALIA - AUSTRALIAN DOLLAR/US$"].isnull().sum()/(df.shape[0])*100
print("Missing Values Percentage",percentage_nan)
# Out:
# Missing Values Percentage 0.0

# %%
values = list(df["AUSTRALIA - AUSTRALIAN DOLLAR/US$"].value_counts().index)
count = list(df["AUSTRALIA - AUSTRALIAN DOLLAR/US$"].value_counts().values)

others = sum(count[10:])
plt.subplots(figsize=(5,5))
plt.barh(values[:10][::-1],count[:10][::-1],color="orange",alpha=0.7)
plt.xlabel("COUNT")
plt.xticks(size=14)
plt.yticks(size=14)
plt.ylabel("TOP 10 VALUES (Most Frequent)")
plt.title("VALUES v/s COUNT")
plt.grid()
plt.show()

# %% [markdown]
# <center><h1>EURO AREA - EURO/US$</h1></center>

# %%
counts = df["EURO AREA - EURO/US$"].value_counts()
percent = df["EURO AREA - EURO/US$"].value_counts(normalize=True) * 100
pd.DataFrame({"Count":counts,"Percentage":percent}).head(10)
# Out:
#         Count  Percentage
# ND        198    3.795285
# 0.9029      9    0.172513
# 0.8898      9    0.172513
# 0.878       9    0.172513
# 0.8814      8    0.153345
# 0.773       8    0.153345
# 0.8131      8    0.153345
# 0.7637      8    0.153345
# 0.7551      8    0.153345
# 0.89        8    0.153345

# %%
percentage_nan = df["EURO AREA - EURO/US$"].isnull().sum()/(df.shape[0])*100
print("Missing Values Percentage",percentage_nan)
# Out:
# Missing Values Percentage 0.0

# %%
values = list(df["EURO AREA - EURO/US$"].value_counts().index)
count = list(df["EURO AREA - EURO/US$"].value_counts().values)

others = sum(count[10:])
plt.subplots(figsize=(5,5))
plt.barh(values[:10][::-1],count[:10][::-1],color="orange",alpha=0.7)
plt.xlabel("COUNT")
plt.xticks(size=14)
plt.yticks(size=14)
plt.ylabel("TOP 10 VALUES (Most Frequent)")
plt.title("VALUES v/s COUNT")
plt.grid()
plt.show()
